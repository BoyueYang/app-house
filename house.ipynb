# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot')
house = pd.read_csv('housing.csv')
house.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
house['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
median_price = house['median_house_value']
median_price.describe()
# Out:
# count     20640.000000
# mean     206855.816909
# std      115395.615874
# min       14999.000000
# 25%      119600.000000
# 50%      179700.000000
# 75%      264725.000000
# max      500001.000000
# Name: median_house_value, dtype: float64

# %%
sns.histplot(median_price, bins = 30,color = [0,0.5,0.5])
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='Count'>

# %%
fig, ax = plt.subplots(figsize=(30,30))
sns.histplot(median_price, bins = 30,color = [0,0.5,0.5])
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='Count'>

# %%
house.median_income.describe()
# Out:
# count    20640.000000
# mean         3.870671
# std          1.899822
# min          0.499900
# 25%          2.563400
# 50%          3.534800
# 75%          4.743250
# max         15.000100
# Name: median_income, dtype: float64

# %%
house[house.median_income < 4.5] and house[house.median_income>2.5]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\Boyue\Desktop\2022 autumn_course\misy225\my-streamlit\house.ipynb Cell 7 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Boyue/Desktop/2022%20autumn_course/misy225/my-streamlit/house.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> house[house.median_income < 4.5] and house[house.median_income>2.5]
#
# File c:\Users\Boyue\.conda\envs\data_science\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
house[(house.median_income < 4.5 ) & (house.median_income>2.5)]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4        -122.25     37.85                52.0       1627.0           280.0
# 5        -122.25     37.85                52.0        919.0           213.0
# 6        -122.25     37.84                52.0       2535.0           489.0
# 7        -122.25     37.84                52.0       3104.0           687.0
# 9        -122.25     37.84                52.0       3549.0           707.0
# ...          ...       ...                 ...          ...             ...
# 20631    -121.40     39.33                15.0       2655.0           493.0
# 20632    -121.45     39.26                15.0       2319.0           416.0
# 20633    -121.53     39.19                27.0       2080.0           412.0
# 20634    -121.56     39.27                28.0       2332.0           395.0
# 20636    -121.21     39.49                18.0        697.0           150.0
#
# ...
